# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Upload TRANSACTION Data From CSV

# %%
#Load Transactions Data 
Transactions= pd.read_csv ('TRANSACTION_TAKEHOME (1).csv')

# %% [markdown]
# ### Data Exploration and Cleaning

# %%
Transactions['FINAL_QUANTITY'] = Transactions['FINAL_QUANTITY'].replace(['', ' '], np.nan)
Transactions['FINAL_SALE'] = Transactions['FINAL_SALE'].replace(['', ' '], np.nan)
Transactions.head()

# %%
Transactions.shape

# Get overview
Transactions.info()

# CHeck missing values
Transactions.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RECEIPT_ID      50000 non-null  object
#  1   PURCHASE_DATE   50000 non-null  object
#  2   SCAN_DATE       50000 non-null  object
#  3   STORE_NAME      50000 non-null  object
#  4   USER_ID         50000 non-null  object
#  5   BARCODE         44238 non-null  float64
#  6   FINAL_QUANTITY  50000 non-null  object
#  7   FINAL_SALE      37500 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 3.1+ MB
# RECEIPT_ID            0
# PURCHASE_DATE         0
# SCAN_DATE             0
# STORE_NAME            0
# USER_ID               0
# BARCODE            5762
# FINAL_QUANTITY        0
# FINAL_SALE        12500
# dtype: int64

# %% [markdown]
# Barcpde has missing values.

# %% [markdown]
# **Check Duplicated Rows**

# %%
Transactions.nunique()
# Out:
# RECEIPT_ID        24440
# PURCHASE_DATE        89
# SCAN_DATE         24440
# STORE_NAME          954
# USER_ID           17694
# BARCODE           11027
# FINAL_QUANTITY       87
# FINAL_SALE         1435
# dtype: int64

# %%
# Display all duplicate rows
duplicated_rows = Transactions[Transactions.duplicated()] .sort_values(by = ['RECEIPT_ID', 'USER_ID'])
print("Duplicated rows:")
print(duplicated_rows)
# Out:
# Duplicated rows:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 45553  007d3232-3990-497f-a081-549e9e7a478b    2024-06-25
# 49759  01a70fe0-026f-4bea-9da4-7d13bbf21e9a    2024-09-02
# 32463  0273cbd8-1620-46c9-8e99-6971e850a2fc    2024-09-08
# 34323  0764c668-2863-49e3-8914-52772620b05d    2024-09-07
# 36222  0be1ab3d-ea77-48a2-b954-7ba1a5a12c79    2024-07-12
# ...                                     ...           ...
# 33356  f2e87c6f-c9ef-4615-9ad2-a1b832f8f69e    2024-07-11
# 43320  f79e00be-fbc1-4a27-b68c-a5f406c9a5e0    2024-09-02
# 48463  f871a430-7fcb-4d95-989e-aa0b57497eca    2024-09-01
# 41604  fa8ab2d7-b051-47d7-bd56-d0d88997d367    2024-07-22
# 46640  fb825ba4-fe3b-45b4-a547-5a33d23e5e33    2024-08-24
#
#                              SCAN_DATE              STORE_NAME  \
# 45553 2024-06-27 21:21:53.442000+00:00  DOLLAR TREE STORES INC
# 49759 2024-09-07 16:02:39.835000+00:00                 WALMART
# 32463 2024-09-08 22:17:11.989000+00:00                 WALMART
# 34323 2024-09-08 10:57:12.252000+00:00                 WALMART
# 36222 2024-07-12 18:09:42.300000+00:00              SAM'S CLUB
# ...                                ...                     ...
# 33356 2024-07-17 08:16:00.771000+00:00  DOLLAR TREE STORES INC
# 43320 2024-09-07 20:24:02.732000+00:00  DOLLAR TREE STORES INC
# 48463 2024-09-07 17:45:11.519000+00:00                  KROGER
# 41604 2024-07-31 21:26:56.929000+00:00                    ALDI
# 46640 2024-08-25 13:58:08.848000+00:00                 WALMART
#
#                         USER_ID         BARCODE FINAL_QUANTITY FINAL_SALE
# 45553  63a8dbf101cb7c888c6ad87d   79200060688.0           1.00       1.25
# 49759  614e733372ba844aa8dc345e   41789001215.0           1.00       0.52
# 32463  60e4f3ac34f82e1344669ee2  681131148320.0           1.00       3.48
# 34323  6390d1f790ad5449ec5e43f7   26200144405.0           1.00       3.98
# 36222  664bf4d27c0469953bf91f44             nan           1.00       3.58
# ...                         ...             ...            ...        ...
# 33356  5e4ef886f1ce71141bb18ed1             nan           1.00       1.25
# 43320  64850eac9d0c925cdc8f9b44   11206005003.0           1.00       1.25
# 48463  615c505eb220b85b9615f063             nan           1.00       1.00
# 41604  653c241b909604bae9074b22             nan           1.00       0.47
# 46640  61ed4fda0605d0323d86dced   78742229492.0           1.00       0.78
#
# [171 rows x 8 columns]

# %% [markdown]
# **Duplicted rows based on Receipt_Id**

# %%
duplicated_rows_rec = Transactions[Transactions.duplicated(subset=['RECEIPT_ID'], keep=False)].sort_values(by = 'RECEIPT_ID') # keep=False marks all duplicates as True
print("Duplicated rows:")
print("Duplicated rows:")
print(duplicated_rows_rec)
# Out:
# Duplicated rows:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 41567  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1      0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 39291  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# ...                                     ...           ...
# 28152  fffbb112-3cc5-47c2-b014-08db2f87e0c7    2024-07-30
# 24998  fffbfb2a-7c1f-41c9-a5da-628fa7fcc746    2024-07-28
# 31602  fffbfb2a-7c1f-41c9-a5da-628fa7fcc746    2024-07-28
# 25233  fffe8012-7dcf-4d84-b6c6-feaacab5074a    2024-09-07
# 24999  fffe8012-7dcf-4d84-b6c6-feaacab5074a    2024-09-07
#
#                              SCAN_DATE STORE_NAME                   USER_ID  \
# 0     2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 41567 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1     2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 39291 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2     2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# ...                                ...        ...                       ...
# 28152 2024-08-04 11:43:31.474000+00:00    WALMART  5eb59d6be7012d13941af5e2
# 24998 2024-07-28 11:47:34.180000+00:00    WALMART  62a0c8f7d966665570351bb8
# 31602 2024-07-28 11:47:34.180000+00:00    WALMART  62a0c8f7d966665570351bb8
# 25233 2024-09-08 08:21:25.648000+00:00  WALGREENS  5f53c62bd683c715b9991b20
# 24999 2024-09-08 08:21:25.648000+00:00  WALGREENS  5f53c62bd683c715b9991b20
#
#               BARCODE FINAL_QUANTITY FINAL_SALE
# 0       15300014978.0           1.00
# 41567   15300014978.0           1.00       1.54
# 1                 nan              0       1.49
# 39291             nan           1.00       1.49
# 2       78742229751.0           1.00
# ...               ...            ...        ...
# 28152  818000020115.0           1.00       4.88
# 24998   13000009546.0           1.00
# 31602   13000009546.0           1.00       3.48
# 25233   74323095777.0           2.00       2.98
# 24999   74323095777.0              0       2.98
#
# [50000 rows x 8 columns]

# %% [markdown]
# The duplicated rows shows there are different FINAL_SALE or FINAL_QUANTITY

# %% [markdown]
# ### Data Quality & Issues
# **1. Convert PURCHASE_DATE & SCAN_DATE to Datetime**
# - The date is a ISO-8601 format, UTC date time.

# %%
Transactions['PURCHASE_DATE'] = pd.to_datetime(Transactions['PURCHASE_DATE'])
Transactions['SCAN_DATE'] = pd.to_datetime(Transactions['SCAN_DATE'])
Transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 0 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2 2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 4 2024-07-05 15:56:43.549000+00:00   RANDALLS  6193231ae9b3d75037b0f928
#
#         BARCODE FINAL_QUANTITY FINAL_SALE
# 0  1.530001e+10           1.00
# 1           NaN              0       1.49
# 2  7.874223e+10           1.00
# 3  7.833997e+11              0       3.49
# 4  4.790050e+10           1.00

# %% [markdown]
# **2. Check if all values in FINAL_QUANTITY and FINAL_SALE are numeric**

# %%
# FINAL_QUANTITY
non_numeric_quantity = pd.to_numeric(Transactions['FINAL_QUANTITY'], errors='coerce').isna()
non_numeric_quantity_rows = Transactions[non_numeric_quantity]
print(f"Rows with non-numeric FINAL_QUANTITY:\n{non_numeric_quantity_rows}")
print(non_numeric_quantity_rows.nunique())

#FINAL_SALE
non_numeric_sale = pd.to_numeric(Transactions['FINAL_SALE'], errors='coerce').isna()
non_numeric_sale_rows = Transactions[non_numeric_sale]
print(f"Rows with non-numeric FINAL_SALE:\n{non_numeric_sale_rows}")
print(non_numeric_sale_rows.nunique())
# Out:
# Rows with non-numeric FINAL_QUANTITY:
# Empty DataFrame
# Columns: [RECEIPT_ID, PURCHASE_DATE, SCAN_DATE, STORE_NAME, USER_ID, BARCODE, FINAL_QUANTITY, FINAL_SALE]
# Index: []
# RECEIPT_ID        0
# PURCHASE_DATE     0
# SCAN_DATE         0
# STORE_NAME        0
# USER_ID           0
# BARCODE           0
# FINAL_QUANTITY    0
# FINAL_SALE        0
# dtype: int64
# Rows with non-numeric FINAL_SALE:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 0      0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 2      00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 4      00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
# 6      000550b2-1480-4c07-950f-ff601f242152    2024-07-06
# 8      000e1d35-15e5-46c6-b6b3-33653ed3d27e    2024-08-13
# ...                                     ...           ...
# 24990  ffeb1ff4-0db9-4cb9-9574-20ec2db3e5ad    2024-08-25
# 24992  ffec42ba-c71d-44da-b8d0-eb529632e87a    2024-06-17
# 24994  fff15a3d-25ea-4c36-b84a-91eb4157daf9    2024-07-19
# 24996  fff6c6c8-e002-4262-85ea-25849d9721db    2024-08-30
# 24998  fffbfb2a-7c1f-41c9-a5da-628fa7fcc746    2024-07-28
#
#                              SCAN_DATE   STORE_NAME                   USER_ID  \
# 0     2024-08-21 14:19:06.539000+00:00      WALMART  63b73a7f3d310dceeabd4758
# 2     2024-08-19 15:38:56.813000+00:00      WALMART  60842f207ac8b7729e472020
# 4     2024-07-05 15:56:43.549000+00:00     RANDALLS  6193231ae9b3d75037b0f928
# 6     2024-07-06 19:27:48.586000+00:00      WALMART  5f850bc9cf9431165f3ac175
# 8     2024-08-13 18:21:07.931000+00:00      WALMART  61a6d926f998e47aad33db66
# ...                                ...          ...                       ...
# 24990 2024-08-25 12:43:19.456000+00:00    FOOD CITY  6246d0d989dfe41b042f2d9d
# 24992 2024-06-17 11:17:21.971000+00:00  WINCO FOODS  6632c5871be3d689ceb875c7
# 24994 2024-07-23 22:43:04.589000+00:00      WALMART  6254a7ea3f2afd3c2fd53d22
# 24996 2024-09-06 18:39:03.161000+00:00      WALMART  6220b111e9e82c0c6bc24534
# 24998 2024-07-28 11:47:34.180000+00:00      WALMART  62a0c8f7d966665570351bb8
#
#              BARCODE FINAL_QUANTITY FINAL_SALE
# 0      15300014978.0           1.00
# 2      78742229751.0           1.00
# 4      47900501183.0           1.00
# 6      49200905548.0           1.00
# 8      52000011227.0           1.00
# ...              ...            ...        ...
# 24990  24842832322.0           1.00
# 24992  41196010138.0           1.00
# 24994  78742128511.0           1.00
# 24996  78742369822.0           1.00
# 24998  13000009546.0           1.00
#
# [12500 rows x 8 columns]
# RECEIPT_ID        12479
# PURCHASE_DATE        89
# SCAN_DATE         12479
# STORE_NAME          602
# USER_ID           10445
# BARCODE            6804
# FINAL_QUANTITY       41
# FINAL_SALE            1
# dtype: int64

# %% [markdown]
# **For FINAL_QUANTITY, the only non-numeric value is the string 'zero' - to ensure future calculation would need to change str 'zero' to numeric 0.
# For FINAL_SALE, the only non-numeric value is blank.**

# %%
Transactions['FINAL_QUANTITY'] = Transactions['FINAL_QUANTITY'].apply(lambda x: 0 if x =='zero' else x)
Transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 0 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2 2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 4 2024-07-05 15:56:43.549000+00:00   RANDALLS  6193231ae9b3d75037b0f928
#
#         BARCODE FINAL_QUANTITY FINAL_SALE
# 0  1.530001e+10           1.00
# 1           NaN              0       1.49
# 2  7.874223e+10           1.00
# 3  7.833997e+11              0       3.49
# 4  4.790050e+10           1.00

# %% [markdown]
# **3.Convert scientific notion to string for Barcode**

# %%
Transactions['BARCODE'] = Transactions['BARCODE'].astype(str)
Transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 0 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2 2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 4 2024-07-05 15:56:43.549000+00:00   RANDALLS  6193231ae9b3d75037b0f928
#
#           BARCODE FINAL_QUANTITY FINAL_SALE
# 0   15300014978.0           1.00
# 1             nan              0       1.49
# 2   78742229751.0           1.00
# 3  783399746536.0              0       3.49
# 4   47900501183.0           1.00

# %% [markdown]
# **4.Date Logic Inconsistencies**

# %%
invalid_dates = Transactions[Transactions['SCAN_DATE'] < Transactions['PURCHASE_DATE']]
print(invalid_dates)
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 51     008c1dcc-0f96-4b04-98c8-2a2bb63ef89d    2024-07-21
# 455    04a320ed-2903-45e5-8fd7-6eaf08daef32    2024-06-29
# 494    05023b3d-5f83-47a7-a17c-8e8521d0bc94    2024-09-08
# 675    06ce3da3-a588-4c37-93b4-0b6d11e42704    2024-06-22
# 870    08d0e78f-3e63-40a3-8eb0-73fdf76da52c    2024-06-22
# ...                                     ...           ...
# 46034  08d0e78f-3e63-40a3-8eb0-73fdf76da52c    2024-06-22
# 46539  718aa730-b62f-4e18-8dba-1d7105dac341    2024-09-05
# 46941  af2b818f-4a92-4e98-958c-65f2ce0b271d    2024-06-15
# 47653  72bb7b71-d958-4a46-ae62-43abdeb0e693    2024-06-15
# 47837  99c2e8dc-9dc7-4267-9342-0b19c3fb35a0    2024-06-15
#
#                        SCAN_DATE            STORE_NAME  \
# 51     2024-07-20 19:54:23.133 Z               WALMART
# 455    2024-06-28 11:03:31.783 Z  DOLLAR GENERAL STORE
# 494    2024-09-07 22:22:29.903 Z             SHOP RITE
# 675    2024-06-21 12:34:15.665 Z              BIG LOTS
# 870    2024-06-21 20:50:01.298 Z  DOLLAR GENERAL STORE
# ...                          ...                   ...
# 46034  2024-06-21 20:50:01.298 Z  DOLLAR GENERAL STORE
# 46539  2024-09-04 20:14:00.374 Z               WALMART
# 46941  2024-06-14 10:57:23.892 Z  DOLLAR GENERAL STORE
# 47653  2024-06-14 19:55:56.672 Z               WALMART
# 47837  2024-06-14 22:07:18.702 Z               WALMART
#
#                         USER_ID       BARCODE FINAL_QUANTITY FINAL_SALE
# 51     5dc24cdb682fcf1229d04bd6  6.811312e+11           zero       3.18
# 455    62855f67708670299a658035  4.900002e+10           zero       6.00
# 494    666a43c77c0469953bfd9ae0  6.414404e+10           2.00        NaN
# 675    646f6ffb7a342372c858487e  3.111117e+11           zero       4.05
# 870    664cafb6e04f743a096a837e  7.680828e+10           2.00        NaN
# ...                         ...           ...            ...        ...
# 46034  664cafb6e04f743a096a837e  7.680828e+10           2.00       3.50
# 46539  5e0f561efa890112094202ad  7.339001e+10           1.00       3.56
# 46941  64de6465516348066e7c5690  8.175130e+11           1.00       3.83
# 47653  649726ea127ddb5d7f0004dc  3.485611e+10           1.00       2.05
# 47837  5e48ddd01a900e141874e241  7.874203e+10           1.00       1.34
#
# [94 rows x 8 columns]

# %% [markdown]
# **5. Check for Categorical Data - STORE_NAME**

# %%
Transactions['STORE_NAME'] .unique()
# Out:
# array(['WALMART', 'ALDI', 'FOOD LION', 'RANDALLS', 'TARGET', 'COSTCO',
#        'DOLLAR TREE STORES INC', 'FAMILY DOLLAR', 'KROGER', 'FOODS CO',
#        'REAES STORE', 'IGA', 'DOLLAR GENERAL STORE', 'PUBLIX', "MACEY'S",
#        'WALGREENS', 'CVS', 'WINCO FOODS', 'THE HOME DEPOT', 'FRED MEYER',
#        'MARKET BASKET', '7-ELEVEN', 'HOBBY LOBBY', 'GIANT EAGLE',
#        'HY-VEE', "SAM'S CLUB", 'WHISPERING PINES FRUIT FARMS',
#        'JEWEL OSCO', 'SHELL', 'NELES GRANACOT', "TRADER JOE'S",
#        'FIVE BELOW', 'GROCERY OUTLET BARGAIN MARKET', 'SMART SHOP',
#        'TINKEN AFB COMMIE', 'ALBERTSONS', 'LIDL', 'PHARMACY', 'WEIS',
#        'FASTRAC', 'RITE AID', 'MEIJER', 'COMMISSARY', 'FOODLAND',
#        'PAL CAMPO RESTAURANT', "BJ'S WHOLESALE CLUB", 'CARRS',
#        'SHOP RITE', 'PLAVERS CAFE LIDA', 'WINN-DIXIE', 'SAFEWAY',
#        'MI TIENDA', 'CIRCLE K', 'NUTS FACTORY 74TH', 'AMAZON', "MARC'S",
#        'WEGMANS', 'SCHNUCKS', 'FOOD DEPOT', 'BURGER KING', 'H-E-B',
#        'PIONEER SUPERMARKETS', 'KING SOOPERS', 'FESTIVAL FOODS',
#        'TJ MAXX', "SMITH'S", "WOODMAN'S MARKET", 'BRAVO SUPERMARKETS',
#        'GOMART', 'HANNAFORD', 'QFC', 'KWIK TRIP', 'MARKET', 'ACME',
#        "LOVE'S", 'FOOD OUTLET', 'HARRIS TEETER', 'STAR MARKET',
#        'THE GIANT CO', 'GIANT FOOD', 'EXPRESS ROSES', 'PRICE CHOPPER',
#        'PAVILIONS', 'FOOD BAZAAR SUPERMARKET', 'JOHN DEERE HQ',
#        'FOOD CITY', 'RALPHS', 'PETCO', 'PONTE FRESCO',
#        "DILLON'S FOOD STORE", 'PUEBLO', 'PICK N SAVE',
#        'PRESIDENTE SUPERMARKETS', 'MAIN STREET MARKET', 'FOOD FAIR',
#        'LA GLORIA SUPERMERCADO', 'FAREWAY', 'STOP & SHOP', 'FOOD 4 LESS',
#        'BIG LOTS', 'ENORTHGATE MARKET', 'YOUR DEKALB FARMERS MARKET',
#        "MARTIN'S SUPERMARKET", 'PRIME TIME NUTRITION', 'THE FRESH MARKET',
#        "WITBECK'S FAMILY FOODS", 'KEY FOOD FRESH',
#        'RIGGINS WATER WHITE MARKET', 'HIBACHI JAPANESE STK HOUSE', 'WAWA',
#        'TOPS MARKETS', 'SUNOCO', 'ROUSES MARKET', 'RABERS',
#        "REDNER'S MARKETS", "DAVE'S MARKETPLACE", "STEW LEONARD'S",
#        "RALPH'S CAQUAS", 'MARSHALLS', 'SUPERMERCADO TORRES',
#        'METRO MARKET', 'FOOD MAXX', "BRAUN'S FOOD CENTER",
#        'FARMERS SUPER MARKET', 'SUPERMAX', "BUEHLER'S FRESH FOODS",
#        'PIGGLY WIGGLY', 'SUPER SAVER', 'SUN MART FOODS', 'EXCHANGE',
#        'CUB FOODS', 'GAS N GO', "JOHN'S GROCERY & HARDWARE",
#        "RIESBECK'S FOOD MARKET", "SHAW'S", 'GIANT',
#        'SAVE MART SUPERMARKETS', 'FLYING J', 'MC',
#        'GIANT FOOD STORE FUEL', 'PRICE CUTTER', 'COMPARE FOODS',
#        'STATER BROS', 'ANAZEH SANDS BILLIARDS', 'ULTA BEAUTY',
#        'SUPER 1 FOODS', 'TOM THUMB', 'SUPREMO FOOD MARKET',
#        'LA BONITA SUPERMARKETS', "IT'SUGAR", 'HOLIDAY MARKET',
#        "KING'S SUPERMARKET", 'SPROUTS FARMERS MARKET', 'FOODTOWN',
#        'LUCKY SUPERMARKET', 'WHOLE FOODS MARKET',
#        'ZOOB ZIB THAI AUTHENTIC NOODLE BAR', 'OSCO', 'EL SUPER',
#        'SUPERMERCADOS SELECTOS', 'LOTTE PLAZA MARKET',
#        'VEGAS FOOD CENTER', 'FAIRPLAY', 'COSICO THOLESALE',
#        'INTERNATIONAL FOODMART', 'FOOD12', 'PATRICK AFB COMMISSARY',
#        'NI PUEBLO', 'SPEEDWAY', 'NORTHGATE MARKET', 'INGLES',
#        'STRACK & VAN TIL', 'BEL AIR', 'DOORDASH DELIV', 'COUNTY MARKET',
#        "FRY'S FOOD STORE", 'SUPER FRESH', 'PAYLESS', 'SAVE A LOT', 'VONS',
#        'PALISADES', 'DOLLAR SAVER',
#        'MAI KET WE DO BEEF THE BEST ALBER TSONS MARKET THE BEST WE DO BEEF',
#        'JAY C FOOD STORES', 'LAZY ACRES', 'SHEETZ', "BROOKSHIRE'S",
#        'TIERMA', "BASHAS'", 'KWIK SHOP', 'ELGIN FRESH MARKET',
#        'RESTAURANT DEPOT', 'FRESCO Y MÁS', 'SMART & FINAL',
#        'THERRESDEROCER', 'MURPHY USA', "BOYER'S  FOOD MARKET", 'VALERO',
#        'CITY MARKET', 'SHOP N SAVE', 'CANARY ROOST', 'ME SALVE',
#        'KISMET BIALYS', "MARIANO'S", 'EXXON', 'AMAZONFRESH', 'COMMI5SARE',
#        'STAUFFERS OF KISSEL HILL', 'CARNICERIA POTOSINA', 'NT GIA',
#        'ING JEFE TACOSAR', 'KROGER FUEL', 'BARGAIN HUNT', 'ECONOFOODS',
#        'FOOD GIANT', 'PRICE UTTER', 'FIESTA MART', 'POPSHELF',
#        'NEW MORNING MARKET', 'WHOLESALE', 'LODE', '4 WAY MEAT MARKET',
#        'QUIKTRIP', 'HANCOCKS NEIGHBORHOOD MARKET', "TEAL'S MARKET",
#        'THE ATLANTIC HOTEL', 'KEY FOOD MARKETPLACE', 'DIERBERGS',
#        'PRICERITE', 'MODERN MARKET', 'SUPERCENTER',
#        "RIDLEY'S FAMILY MARKETS", 'BELMONT MARKET', 'TOOU ORDG',
#        'COSTCO FUEL', "BELACINO'S", 'GRECIAN STEAKHOUSE',
#        'RRIENO SOUR A RALS LGROCERH', 'WBC HOB', 'GHUIRKS',
#        "LOWE'S HOME IMPROVEMENT", '1AINTING CUSVAL BISTRO',
#        'SUN VALLEY FINE FOODS', 'AMVETS POST 11', 'VALLEY PHARMACY',
#        'NOB HILL FOODS', 'DOLLAD ENEROL', 'KTA SUPER STORES', 'BOJANGLES',
#        "TONY'S FRESH MARKET", 'SEHERAL', 'BEAUTY SUPPLY',
#        'LA’BONNE’S MARKETS', 'TORT SAM TNTON COMMISSARY', 'FIVE BELOV',
#        'ALCT', 'MACS FRESH MARKET', 'SENTARA LEIGH DUTNATIENT',
#        'BIENVENIDOS MEXICAN RESTAURANT', 'RIVERVIEW FAMILY CENTER',
#        'ERMERCADOS SUPE MR. A PEG', 'FAST TRACK', 'SUPER SUPERMARKET',
#        'FRESH THYME MARKET', "SLEEPERS' MARKET", 'CENTER',
#        'SUPERMERCADOS ECONO', 'MACE YS ARKET', "OWEN'S", 'SALONCENTRIC',
#        'VALUEFRESH', 'CO COM', 'VALLARTA SUPERMARKETS', 'CF MARKS',
#        "CATTLEMAN'S ROADHOUSE", 'EWAY SAR', 'AVI FOODSYSTEMS, INC.',
#        'THE FRESH GROCER', "REASOR'S", "CHAPPELL'S HOMETOWN FOODS",
#        'OMPE GFOODS', "ANDRONICO'S COMMUNITY MARKETS", 'RACETRAC',
#        'CAMIL/DOTLAR', 'ROSES', 'MENARDS', 'FLOWERS BAKING CO',
#        'NORTHWOODS WHOLESALE OUTLET', 'LEWER CSCO',
#        'DEFENSE COMMISSARY AGENCY', "WEBSTER'S MARKETPLACE", 'RIGGINS',
#        'MOSQUITO BOOKSLKOBUK TO GO', 'E W JAMES & SONS SUPERMARKETS',
#        'SUPERIOR GROCERS', "CASEY'S GENERAL STORE", 'CARDENAS',
#        'UNSHINE HSE HATH FOODS', "KOHL'S", "BROULIM'S", 'FRESH 4 LESS',
#        'MILLS FLEET FARM', 'ROCHE BROS. SUPERMARKET', 'ARMITAGE PRODUCE',
#        'OFFICE SUPPLIES DORADO SCHOOL &', "NEEDLER'S FRESH MARKET",
#        'GENERAL DISCOUNT', "RALEY'S", 'OUR PHARMACY', 'HUDSON',
#        "CASEL'S SUPERMARKET", 'DILLONS COOC STORES',
#        'ESTRELLA SUPER MARKET', 'HOMETOWN GROCERY', 'MINT CO FO0 S',
#        'ASIA MARKET', "DICK'S SPORTING GOODS", "J'S SALVAGE", 'STAPLES',
#        'CREST FOODS', "REONER'S", 'GW SUPERMARKET', 'CASH WISE', 'RU',
#        'ROCHITA PLAZA MARK', 'LVERYONE', 'FORT JACKSON COMMISSARY',
#        'EAMTLY RESTAURANT', 'PRICELESS FOODS', 'AL', 'CASH SAVER',
#        'EATALY', "MIKE'S DISCOUNT FOODS", 'AMIGO', 'DISCOUNT DRUG MART',
#        'SUPER DISCOUNT TOBACCO', 'MERCHANT COU', "DETWILER'S FARM MARKET",
#        'FIESTA FOODS', 'BETHPAGE PHARMACY', 'SODLE PHARMACY', 'H MART',
#        'NAM DAE MUN FARMERS MARKET', "FROOGEL'S",
#        'THRIFTY PRODUCE & MEAT', 'RHODES FAMILY PRICE CHOPPER',
#        'LOWES FOODS', 'MARKET STREET', "MOSER'S DISCOUNT FOODS",
#        'SPARKLE MARKET', "JUNGLE JIM'S INTERNATIONAL MARKET",
#        'HARPS FOOD STORES', 'TOP TOMATO', "FRESH N' LOW",
#        'SCHEDULE & SAVE', 'SCHOFIELD BARRACKS COMMISSARY',
#        'TOTAL WINE & MORE', 'CHICK-FIL-A', 'GREAT GIANT SUPERMARKET',
#        'GERBES SUPER MARKETS', "CROSBY'S", 'VIET HOA INTERNATIONAL FOODS',
#        'TORO DE ORO MARKET', 'MART', 'TOTOPOS MEXICAN GRILL',
#        'CINEMARK THEATRES', 'LOS AZTECAS', 'MARKET 32', 'DSALONCENTRID',
#        'SHOP FAIR SUPERMARKETS', 'NEIGHBORHOOD DISCOUNT SUPERMARKET',
#        'BIG Y WORLD CLASS MARKET', 'C TCO LESALE WHO', "PETE'S MARKET",
#        'POULEVARU', 'C&C CANDIES', "DODGE'S", 'MD ORIENTAL MARKET',
#        'DRIVE-IN RESTAURANT JUSTRITE', "TRIG'S",
#        'JACKSONVILLE NAS COMMISSARY', "RU'S", 'THE OAK CUPBOARD',
#        'TEK MARKETS', "SCHIEL'S FAMILY MARKET", 'SHOPPERS', "BAKER'S",
#        "SAITO'S JAPANESE STEAKHOUSE", 'COUNTRY MART',
#        'TRADE FAIR SUPERMARKET', 'PILOT', 'MARTINDALES NATURAL',
#        'MARKETPLACE FOODS', 'LUNDS & BYERLYS', "WOME'S",
#        "CARALUZZI'S MARKET", 'BIG DEAL OUTLET', 'CONOCO', 'MART WALR',
#        'ROYAL FARMS', 'LIHE HORSESHOB', 'DILLONS FUEL', "WOODMAN'S FUEL",
#        'SUNSET FOODS', 'PATRIOT STORE', 'STOLE25', 'SUPER BRAYD',
#        "SCHNEIDER'S MARKET", 'BROOKSHIRE BROTHERS',
#        'EL INDIO - MANCHESTER', 'H. YANIRIS', "SON'S PARRISH",
#        'FRESH FOODS', 'SELEDLOS BE TODO/AGUSTO', "GERRITY'S SUPERMARKETS",
#        'NELLIS AFB COMMISSARY', "HORNBACHER'S", 'COUNTRY MARKET INC.',
#        'YOODS CY', "PATON'S MARKET PLACE", 'APPLES GROCERY STORE',
#        'COMMUNITY MARKETS', "UNCLE GIUSEPPE'S MARKETPLACE",
#        "CONCESSI'S FURO MARKET", "MICHAEL'S", 'OCRACOKE VARIETY',
#        'BOONEVILLE SHOPWISE', 'KARNS QUALITY FOODS', 'PENN SPARKLE',
#        "DE' FRESH MARKET", 'SHOP A LOTT', 'PONTS FRESCO', 'ROYALS LIQUOR',
#        'THE TURN CLUB', 'FAMILY FARE SUPERMARKETS',
#        'TYNDALL AFB COMMISSARY', 'ST LUKES OUTPATIENT',
#        'RMERCADOS SUPER MRO PEOA', 'CHEVRON', '10BOX COST-PLUS',
#        'A CME DURP SUPERAK', 'DEJAN', 'FOOD KING', "RIC'S FOOD CENTER",
#        'NEW ASIA SUPERMARKET', 'PIER17', 'FINE FARE SUPERMARKET',
#        'KING KULLEN', "BUDDY'S CRABHOUSE OYSTER BAR",
#        "OZZIE'S FRESH MARKET BY FOOD UNIVERSE", 'MARKET FRESH',
#        'THE BACK FORTY', 'FIRELAKE EXPRESS GROCERY', 'ACE HARDWARE',
#        'FRESHCO', 'HOSPITAL DRIVE PHARMACY', 'CHERRY VALLEY MARKETPLACE',
#        'JR FOOD', 'WESTERN BEEF', "RALEY'S SERVICE CENTER AT", 'TACO RIO',
#        'JCPENNEY', 'FOODARAMA', 'AR DISNEY WORLD.',
#        'SUPERMERCADO NAPO VELEZ', 'NAVARRO DISCOUNT PHARMACIES', 'SIESCA',
#        'SHOPPERS VALUE FOODS', 'BAPTIST HEALTH', 'HARVEYS SUPERMARKET',
#        'KINNEUDRUGS', 'WHITE & CASE CAFE', 'LA PANZA FELIZ',
#        'SES MOO MARKET', 'LA FRONTERA', "IL''S WHIOLESALE CLUB",
#        'MARATHON', 'KWIK FILL', 'KWIK STAR', 'SSARY COMMI', "DICK'S",
#        'CHANGSFOOD2020', 'CRE ST FOODS', 'WOODEN NICKEL',
#        'BUFORD HIGHWAY FARMERS MARKET', "K ENT 'S MARKE", 'HARTIG',
#        'NORDSTROM', 'FOOD ZONE', "BRAUM'S ICE CREAM AND DAIRY STORES",
#        'WWW.SHOPMAR MARVE', 'SPIRITS', 'FORT BUCHANAN COMMISSARY',
#        'HOMELAND', 'FARM FRESH', 'ALTA', 'FREAMEYER', 'SES 00 W MARKET',
#        'LEPPINKS FOOD CENTERS', "SCHULTE'S FRESH FOODS", 'LA MICHOACANA',
#        'THE S HHANT OR 2010 MMILY RN /TAVES', 'HOLIDAY STATIONSTORE',
#        'SHORT STOP', 'SAN DIEGO NB COMMISSARY', '/MART',
#        'BIG SAVER FOODS', "GORDON'S SELECT MARKET", 'ARIES SUPERMARKET',
#        'PEPPERIDGE FARM', 'SCOTT AFB COMMISSARY', 'FESTIT AL',
#        "CLULS SAM'S", 'VENTURE FOODS', "LAURA'S PHARMACY",
#        'MOUNT AIN SUPER FRESH MARKET', 'FARMACIA CORCOVAPA',
#        'THE HALF WALL BEER HOUSE', "HELEN'S OF ELLSWORTH", 'EXPRESS LANE',
#        'TOWN & COUNTRY SUPERMARKET',
#        'APERMERCADOSS MRS PORQUE TU ARUS ESCOCININ', 'YALLAH TACO',
#        'SUMMA HEALTH', 'SELLERS BROS', "BUTCHER'S BREWHUIS", 'STORE',
#        'UNITED SUPERMARKETS', 'HARRIS TEETER FUEL', "CHAMPAGNE'S MARCHE",
#        'WESTERN UNION', 'THE FRIDGE', 'H.F DOLLAR & UP', 'CORRAL',
#        'CERMAK FRESH MARKET', 'AZUCAR CUBAN CUISINE', 'SE ECTOS',
#        'TROYER COUNTRY MARKET', "WOODRUFF'S MARKET", 'NEW HEIGHTS GRILL',
#        'JHYRANI L- SUPER', 'UNIVERSITY AVENUE MARKET',
#        'ALPINE MARKETPLACE', 'SUNSHINE FOODS', "LOWE'S MARKET",
#        "BUC-EE'S", 'VITACOST', 'LAKEWOOD SUPERVALU',
#        'BOTTOMS UP WINE  LIQUOR', 'HOLIDAY OIL', 'LA PLACITA SUPERMARKET',
#        "JOHNSON'S FOOD", 'M & W MARKET', 'RISK', 'LIBERTY MARKET',
#        'MAYPORT NS COMMISSARY', "BENNETT'S PIT BBQ-GATLINBURG",
#        'AT RED HAWK RESORT  CASINO', 'TRANSACTION RECEIPT', 'MANET', 'BP',
#        'TIENDA EL PAISANO', 'CTOWN SUPERMARKETS', 'NORTHOATE 22 KKET',
#        'DANDY MINI MART', 'JONS INTERNATIONAL MARKETPLACE', 'SUPER',
#        'PETSMART', 'DOLLAR KING', 'AUSABLE INN', 'MET FOODMARKETS',
#        'CAMP PENDLETON COMMISSARY', 'SUPERVALU FOODS', "CLARK'S MARKET",
#        'HORNINGS OF', 'R P DY', 'FOOD DALESS PREE', 'THE ROOF',
#        'THE MARKET AT BIRCH BAY', 'LA FIESTA SUPERMARKETS',
#        "BROOKSHIRE'S FOODA PHARMACY", 'FARMACIA CARIDAD', 'MEYER',
#        'CANTORO ITALIAN MARKET', 'DIAMONDSCAN', 'FOOD RAN', 'B',
#        "BERKOT'S SUPER FOODS", 'EXPRESS', 'LONGS DRUGS', "PHO KITCH'N",
#        'SEPHORA', 'STKES FRACH FOODE', 'STRIPES',
#        "KESSLER'S FOOD & LIQUOR", 'SUPERDESCUENTOS MORALES INC',
#        'THE OAKS GRILLE', 'QUALITY MARKET', 'FOID STORES', 'GLACT',
#        'Y DULCERIA LA BONITA PALETERIA', 'BEAUTY OUTLET OF HAMPTON',
#        'LOL', 'CURAAR SHOPPING CANTER', 'FISH HOUSE', 'S AVEIAL',
#        'KING SOOPERS FUEL', 'DVERS1OCK DISCOUNT CNTR',
#        'SEAFOOD CITY SUPERMARKET', "JUNIOR'S SUPERMARKET",
#        'FORT NOVOSEL COMMISSARY', 'DOG STREET', 'TELWAY', 'LA CONFIANZA',
#        'BREAK TIME', 'FOOD FAIR SUPERMARKET', 'THE TRUE LOW PRICE LEADER',
#        'THORNTONS', 'APP LE MARKET', 'ALOHA FROM BLIND VENDORS',
#        'NICHOLASYILLE', 'BAILEYS PRODUCE & NURSERY',
#        'ADAMS FAIRACRE FARMS', 'ALBERGUE OLIMPICO',
#        'CARNICERIA LOS DOS RIOS', 'EL CABRITO MEXICAN RESTAURANT',
#        'S DRN MY', 'MAPCO MART', 'TART TINS', 'MONONGAHELA',
#        "K'S BESTWAY GROCERY", 'MARINE CORPS EXCHANGE', 'PHILLIPS 66',
#        'ALOME CINEMA GRILL', 'FANCY FRUIT & PRODUCE', 'KUM & GO',
#        "SEDANO'S", 'ALAYO', "R REDNER'S SINCE 1976", 'PRESTON FOODS',
#        'TINKER COMMISsARY', 'ASIAN HARBOR', 'GASOLINE ALLEY',
#        'VALLEY FOOD SUPERMARKET', 'ELA VIR BE', 'PITT STOP',
#        "F OOD TORES RY'S", 'BOOTLEGGERS LIQUOR OUTLET', 'PARALARRIS',
#        'EREWHON MARKET', 'WTHOGANS', "STEWART'S MARKETPLACE",
#        "FRANK'S FRESH MARKET", 'FORT MCCOV COMMISSARY', 'FUEL CITY',
#        'URB. CUIDAD', 'SGROCERY & VARIETY-', 'RULER FOODS',
#        'COLUMBIA ORTHOPA', 'HY MMPLOYEECWNID', 'DILLONS 7OO STUBES',
#        'HU VEE EHPLOVER CUNED', 'GREEN HILLS FARM', 'PATEL BROTHERS',
#        'BI-MART', 'SPINX', "ALLSUP'S", 'MEXICO MARKET',
#        'NORTHOATE MARKETR', 'SAV-A-LOT CENTERS NUTRITION',
#        'MONONGAHELA HOSPITAL', "QUINN'S SUPER MARKET", 'FIESTA GRANDE',
#        'SAV-ON PHARMACY', 'FAIRPLAY FINER FOODS', 'GET-GO',
#        'BASKET ARKET', "FRY'S FOOD AND DRUG FUEL", 'CARNICERIA GONZALEZ',
#        'EDWARDS FOOD GIANT', 'OMC SMOKEHOUSE', "HUGO'S",
#        'CITY FRESH MARKET', 'SHCOTOS', 'CEE BEE FOOD STORE',
#        'WEEMERS DISCOUNT GROCERIES', 'HAWES MMARKETH', 'DISTRICT MARKET',
#        'BIG BOSS BIG BOSS', 'MINARE', 'FOOD WORLD SUPERMARKET',
#        'URBAN PIE', 'CUMBERLAND FARMS', 'BROTHERS FOOD MARKET',
#        'OVAL SUPERA', 'PEN MART,', 'WAIMA', "R REDNER'S 1970",
#        'LEWIS DRUG', 'WEE', "RU MEASUR'A", 'ASTAN FOOD MAK',
#        'BLISS BEAUTY SUPPLY', "HATILLO KASH N' KARRY", "MACY'S",
#        'GROCERY', 'GLENWOOD FOODS', 'IPHARMACY', 'STOTER R BROS MARKETS',
#        'HARPS MOMETOWN FRE4M', 'ALAYOS', 'KHOUT', 'MI RANCHO SUPERMARKET',
#        'MAEEYS HOPPY', "HORNING'S MARKET OF BETHEL",
#        'NBK BANGOR COMMISSARY', 'FODD WLESS', 'PLAZA LIQUORS',
#        'EL RIO GRANDE', 'BLUE SUNERESH', "WENDY'S", 'THE FOOD EMPORIUM',
#        "OLLIE'S BARGAIN OUTLET", 'CENEX', 'MI PUEBLO', 'DORITOS SS BOGO',
#        'THERRESNEROCER', 'LIQUOR & CONVENIENCE STORE', 'TERRY DRUGS',
#        'TARJET', 'HOMETOWN FOODS', 'BEAUTY EXCHANGE', 'PHARMAMAX',
#        'SUNFLOWER', "ARMANDO'S SUPERMARKET", 'F RY',
#        'DECICCO FAMILY MARKETS', 'HANSCOM COMMISSARY', 'HOMETOWN 15',
#        'FRESH VALUE', 'JOLLA BELLA BEAUTY SUPPLY',
#        'EL RANCHO SUPERMERCADO', 'LOT-LESS CLOSEOUTS',
#        "ANGELI'S CENTRAL MARKET", 'FOODWAY', 'COPPS', 'EL MOLCAJETE LOCO',
#        'MARKETON', 'BAINBOW GROCERY', 'HANDY PANTRY', 'WILDFIRE',
#        'BUTLER FARM MARKET', "DAN'S SUPERMARKET", 'HACKENSACK MARKET',
#        'ORD COMMUNITY COMMISSARY', 'SARASWATI 1 INC', "BELL'S FOOD STORE",
#        'EMART ISMEN', 'AUTOZONE', 'OLD NAVY', "JANE'S PHARMACY",
#        'HARPS MOMHTCWH PBKS', 'INCO FOODS', 'SURPLUS OUTLET',
#        "JOE V'S SMART SHOP", 'ALQI', 'TL FES VEY', 'FRESH WORLD',
#        'FOOD STORES', 'TOM WIML', 'FOOD RITE', 'DUANE READE',
#        "ROOHE'S IGN MAXCICLACE", 'SSARY COMMI INCY',
#        'WALNUT CREEK CHEESE', 'CONMONIENCE', 'SAR', 'ANDERSEN AFB',
#        'MAXWAY', 'KSHO2, INC', "RAMEY'S MARKETPLACE", 'SOVAELAFTA',
#        'PATA NEGRA', 'AZTECA SUPERMERCADO', '99 CENTS ONLY STORES',
#        'VILLAGE SOAP CO. KITCHEN KETTLE VILLAGE', 'GROCERY MART',
#        'RRIS TEETER HAT NEIOHBORHOOD MARKET', 'PIC PAC SUPERMARKET',
#        'COST LE5S', "GREEN'S", "GENO'S SPORTS BAR AND GRILL",
#        'LOAF N JUG', 'SFIC.', 'SBER S COUNTA STORE BULK FOOD',
#        "ELROD'S COST PLUS", 'AT HOME', 'SHORTONE MARKET', 'MAVERIK',
#        'BEAUTY DEPOT', 'HEBOES WEST', 'CHY', "HEINEN'S",
#        'NORTH SHORE FARMS', 'DREAM MARKET', 'SOOPER',
#        "DICKEY'S BARBECUE PIT", 'COST LESS FOOD COMPANY',
#        'BESTWAY SUPERMARKET', 'SUPER MERCADO MEXICO',
#        'SUPERMERCADOS MR. SPECIAL', "BUTCHER'S GRILLE", 'FARMERS',
#        '7TH HEAVEN', 'BANLAFOR', 'MILLERS WHERE COSTS S YOU LESS',
#        "ANAYA'S MARKET", 'RN EFOO', 'SPRIROFIALS', 'FATRVTEW PHARMACY',
#        'INHNITY CARE', 'GOODWILL', 'NYC FRESH MARKET', 'ANPOCNMNA',
#        'STOM LAMIARDS', 'GRANTS SUPERMARKET', 'CHEF CHEN ASIAN CUISINE',
#        'R-N MARKET', 'PANINIS', 'MISS MAMIES', "WEIGEL'S", 'EL-DCE',
#        "ETWILER'S FARM MARKET FRESH FOR LESS",
#        "SHERM'S THUNDERBIRD MARKET", 'JUST SAVE FOODS',
#        "HUGO'S FAMILY PHARMACY", 'RATON TRUCK STOP',
#        'FORT STEWART COMMISSARY', 'ELK COUNTY FOODS', 'VIGROCEE',
#        'CAMP LEJEUNE MCB COMMISSARY', 'CONTINENTAL MIDTOWN',
#        'WAIANAE STORE', 'ASSOCIATED SUPERMARKET', '57 BAYARD STREET',
#        'GLENWOOD FOODS AT GREENCASTLE', 'SUPER MERCADO MONTERREY',
#        'BELEVILLE PHARMACY', 'NOGALES LLC MARKET',
#        'MELROSE FAMILY FASHIONS', "WALT CHURCHILL'S MARKET",
#        'EL SOL MEAT MARKET', 'FOOD MARKET LA CHIQUITA',
#        'OSCEOLA FOOD MART', 'BEMGAORS', 'FORT MYER COMMISSARY',
#        'DELISH NEW AMERICAN GRILL', 'LOCUST VALLEY MARKET', 'FOOD BASKET',
#        'BURKES OUTLET', "BB'S GROCERY OUTLET",
#        "FSCARFALLOTO' HOMETOWN MARKET", 'DRIVE YHRU',
#        'CANNON AEB COMMISSARY', 'FINE WINE & SPIRITS STORES',
#        "DOUG'S SUPERMARKET", 'OUTLET BEAUTY SUPPLY', 'FOOD DYNASTY',
#        'PIC-PAC', 'WOODS SUPERMARKET', 'WINGCRAFT', 'WEAVER MARKETS',
#        'FARMACIAS PLAZA', 'MIDWEST', 'THRIVE MARKET', 'CITGO',
#        'PETRO SERVE USA', 'STOOKEY MART', 'EL REY SUPER FOODS',
#        'RT 10 FARMERS MARKET', "SENDIK'S FOOD MARKET", 'WHISKEY RANCH',
#        "SAM'S FARMERS MARKET", 'NU CASSEL PHARMACY', 'P PHARMACU',
#        'AMERIMART', 'QUIKSTOP', 'KINNEY DRUGS',
#        "INCOLLINGO'S FAMILY MARKET", "JIMMY'S STEAKOUT",
#        'GREAT WALL SUPERMARKET', 'BNDGE STREET PHARMACY IC',
#        "KUHN'S MARKET", 'BOTTLE KING', 'TARERMARKET',
#        'MEKONG SUPERMARKET', 'S RESTAURANTS', 'FOOD LESS THE TRUE LAW',
#        'TOWN & COUNTRY FOODS', "COBORN'S", 'ALAYSOO',
#        'GORDON FOOD SERVICE STORES', 'SAV MOR FOODS', 'TOWN & COUNTRY',
#        'P&L COUNTRY MARKET', 'GIAST', "PARKER'S KITCHEN",
#        'CULEBRA MEAT MARKET', "LANDI'S SUPERMARKET", 'SUPERMARKETS',
#        'MI TIERRA SUPERMERCADO', 'THOMAS MARKET',
#        'EL MARIACHI RESTAURANT', 'SPAGO', 'ASIAN MARKET',
#        'TRAVELCENTERS OF AMERICA', 'MARSEILLES FAMILY RESTAURANT',
#        "HERBIE'S BURGERS", "SEITTER'S MARKET",
#        "MCKEEVER'S MARKET & EATERY", 'NEW WEST ZONE SUPERMARKET',
#        "MANAFORD'S", 'SUPER MERCADOS EL GUERO', 'RELECIOS A/MEOR PRECIOR',
#        'THE MARINERS', 'BLACK BEAR BAR & GRILL', 'MARKETPLACE',
#        'CHAR&LEMON', 'FUNCTIONOFBEAUTY.COM', 'EL CHURRASCASO, GRILL',
#        'ONE STOP', 'HURLBURT FIELD COMMISSARY', 'POPEYES', 'STOTER BROS',
#        "TOM'S FOOD MARKETS", 'RULLI BROS', 'CAPRI',
#        'TARMACIA SAN ANTONIO', 'SOMA', 'AG PIZZA',
#        'FORT CARSON COMMISSARY', "ALACURT'S", 'REDMEYER',
#        'PENNY PINCHERS', 'YESWAY', 'PHARMAMAY CABO RJO', 'MERCATE',
#        "BUSCH'S FRESH FOOD MARKET", 'MCX', "JACK'S MARKET", 'ASHOPPERS',
#        'TO GO STORE', 'FOOD COUNTRY USA', 'PLATEAU TRAVEL CENTER'],
#       dtype=object)

# %% [markdown]
# The quality for STORE_NAME looks good.
